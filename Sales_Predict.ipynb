# %% [markdown]
# # TASK 5 : SALES PREDICTION USING PYTHON

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.drop(['Unnamed: 0'], axis=1)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # Predicting TV Sales

# %%
plt.figure(figsize=(16,8))
plt.scatter(
    df['TV'],
    df['Sales'],
    c='black'
)
plt.xlabel('Money spent on TV ads ($)')
plt.ylabel('Sales ($)')
plt.show()

# %%
X = df['TV'].values.reshape(-1,1)
y = df['Sales'].values.reshape(-1,1)

lr = LinearRegression()
lr.fit(X, y)

print("The linear model is: Y = {:.5} + {:.5}X".format(lr.intercept_[0], lr.coef_[0][0]))
# Out:
# The linear model is: Y = 7.0326 + 0.047537X

# %%
predictions = lr.predict(X)

plt.figure(figsize=(16, 8))

plt.scatter(
    df['TV'],
    df['Sales'],
    c='black'
)

plt.plot(
    df['TV'],
    predictions,
    c='green',
    linewidth=2
)

plt.xlabel("Money spent on TV ads ($)")
plt.ylabel("Sales ($)")
plt.show()

# %%
def predict_sales_value(tv_ads_value):
    return 7.0326 + (0.047537 * tv_ads_value)

# %%
predict_sales_value(230.1)
# Out:
# 17.970863700000002

# %%
predict_sales_value(150)
# Out:
# 14.163150000000002

# %% [markdown]
# # Predicting Radio Sales

# %%
plt.figure(figsize=(16,8))
plt.scatter(
    df['Radio'],
    df['Sales'],
    c='black'
)
plt.xlabel('Money spent on Radio ads ($)')
plt.ylabel('Sales ($)')
plt.show()

# %%
X = df['Radio'].values.reshape(-1,1)
y = df['Sales'].values.reshape(-1,1)

lr = LinearRegression()
lr.fit(X, y)

print("The linear model is: Y = {:.5} + {:.5}X".format(lr.intercept_[0], lr.coef_[0][0]))
# Out:
# The linear model is: Y = 9.3116 + 0.2025X

# %%
predictions = lr.predict(X)

plt.figure(figsize=(16, 8))

plt.scatter(
    df['Radio'],
    df['Sales'],
    c='black'
)

plt.plot(
    df['Radio'],
    predictions,
    c='green',
    linewidth=2
)

plt.xlabel("Money spent on Radio ads ($)")
plt.ylabel("Sales ($)")
plt.show()

# %%
def predict_sales_value(radio_ads_value):
    return 9.3116 + (0.2025 * radio_ads_value)

# %%
predict_sales_value(37.8)
# Out:
# 16.9661

# %%
predict_sales_value(150)
# Out:
# 39.686600000000006

# %% [markdown]
# # Predicting Newspaper Sales

# %%
plt.figure(figsize=(16,8))
plt.scatter(
    df['Newspaper'],
    df['Sales'],
    c='black'
)
plt.xlabel('Money spent on Newspaper ads ($)')
plt.ylabel('Sales ($)')
plt.show()

# %%
X = df['Newspaper'].values.reshape(-1,1)
y = df['Sales'].values.reshape(-1,1)

lr = LinearRegression()
lr.fit(X, y)

print("The linear model is: Y = {:.5} + {:.5}X".format(lr.intercept_[0], lr.coef_[0][0]))
# Out:
# The linear model is: Y = 12.351 + 0.054693X

# %%
predictions = lr.predict(X)

plt.figure(figsize=(16, 8))

plt.scatter(
    df['Newspaper'],
    df['Sales'],
    c='black'
)

plt.plot(
    df['Newspaper'],
    predictions,
    c='green',
    linewidth=2
)

plt.xlabel("Money spent on Newspaper ads ($)")
plt.ylabel("Sales ($)")
plt.show()

# %%
def predict_sales_value(newspaper_ads_value):
    return 12.351 + (0.054693 * newspaper_ads_value)

# %%
predict_sales_value(69.2)
# Out:
# 16.1357556

# %%
predict_sales_value(150)
# Out:
# 20.554949999999998
